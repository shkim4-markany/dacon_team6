# %% [markdown]
# # **신용카드 사용자 연체 예측 프로젝트**

# %% [markdown]
# * [사진] 첨부해야 함

# %% [markdown]
# ### **1. 소개**
# *어서 와요🎵<br> 곧 떠나겠지만🎵<br> 잠시나마 즐거웠어요~🎵<br>*<br>
# *~스텔라장 <월급은 통장을 스칠 뿐>*~<br><br>
# 돈 쓸 일 정말 많은 현대 사회! 현대인에게 신용카드는 없어서는 안 될 존재죠😂<br>
# 여러분은 신용카드 많이 사용하시나요?<br>
# 저희가 이번에 함께할 프로젝트는 신용카드 사용자 연체 예측입니다.

# %% [markdown]
# ### **2. 목적**
# 은행은 어떤 고객들에게 신용카드를 발급해줘야 할까요?<br>
# 신용이 좋은 사람일수록 은행이 신용카드를 발급해주기 편할 겁니다.<br>신용카드 사용 고객들에 관한 데이터를 토대로 이들의 연체 여부를 예측해 보겠습니다!
#
# 이번 프로젝트를 통해 기초적인 데이터 분석 과정과 **Classification(분류) 문제**를 경험하면서 실제 대회에서 사용할 수 있는 기법을 익혀 나가세요!
